# %% [markdown]
# ## CBC [ Study , Analysis , Detection ]
# <img src="binary.png" alt="Drawing" width="4000"/>

# %% [markdown]
# # 1 . 1  Load and Explore the Data

# %%
#  Environment preparation
import os
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# !cd NHANES
# !pwd
# Out:
# /bin/bash: line 1: cd: NHANES: No such file or directory
# /home/tallawi/CBC _model/NHANES

# %%
file_paths = [f'cbc{i}.XPT' for i in range(1, 14)]

# Read each file and view its information.
all_data = []
for file in file_paths:
    df = pd.read_sas(file, format='xport')  # قراءة الملف بصيغة xpt
    print(f'Info for {file}:')
    print(df.info())  # عرض معلومات الملف
    print('========================================')
# Out:
# Info for cbc1.XPT:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8727 entries, 0 to 8726
# Data columns (total 23 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SEQN      8727 non-null   float64
#  1   WTPH2YR   8727 non-null   float64
#  2   LBXWBCSI  7593 non-null   float64
#  3   LBXLYPCT  7582 non-null   float64
#  4   LBXMOPCT  7582 non-null   float64
#  5   LBXNEPCT  7582 non-null   float64
#  6   LBXEOPCT  7582 non-null   float64
#  7   LBXBAPCT  7582 non-null   float64
#  8   LBDLYMNO  7582 non-null   float64
#  9   LBDMONO   7582 non-null   float64
#  10  LBDNENO   7582 non-null   float64
#  11  LBDEONO   7582 non-null   float64
#  12  LBDBANO   7582 non-null   float64
#  13  LBXRBCSI  7593 non-null   float64
#  14  LBXHGB    7593 non-null   float64
#  15  LBXHCT    7593 non-null   float64
#  16  LBXMCVSI  7593 non-null   float64
#  17  LBXMC     7593 non-null   float64
#  18  LBXMCHSI  7593 non-null   float64
#  19  LBXRDW    7593 non-null   float64
#  20  LBXPLTSI  7593 non-null   float64
#  21  LBXMPSI   7593 non-null   float64
#  22  LBXNRBC   7582 non-null   float64
# dtypes: float64(23)
# memory usage: 1.5 MB
# None
# ========================================
# Info for cbc2.XPT:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13772 entries, 0 to 13771
# Data columns (total 22 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SEQN      13772 non-null  float64
#  1   LBXWBCSI  12156 non-null  float64
#  2   LBXLYPCT  12151 non-null  float64
#  3   LBXMOPCT  12151 non-null  float64
#  4   LBXNEPCT  12151 non-null  float64
#  5   LBXEOPCT  12151 non-null  float64
#  6   LBXBAPCT  12151 non-null  float64
#  7   LBDLYMNO  12151 non-null  float64
#  8   LBDMONO   12151 non-null  float64
#  9   LBDNENO   12151 non-null  float64
#  10  LBDEONO   12151 non-null  float64
#  11  LBDBANO   12151 non-null  float64
#  12  LBXRBCSI  12156 non-null  float64
#  13  LBXHGB    12156 non-null  float64
#  14  LBXHCT    12156 non-null  float64
#  15  LBXMCVSI  12156 non-null  float64
#  16  LBXMC     12156 non-null  float64
#  17  LBXMCHSI  12156 non-null  float64
#  18  LBXRDW    12156 non-null  float64
#  19  LBXPLTSI  12156 non-null  float64
#  20  LBXMPSI   12156 non-null  float64
#  21  LBXNRBC   12151 non-null  float64
# dtypes: float64(22)
# memory usage: 2.3 MB
# None
# ========================================
# Info for cbc3.XPT:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 557 entries, 0 to 556
# Data columns (total 22 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SEQN      557 non-null    float64
#  1   LB2DAY    551 non-null    float64
#  2   LB2WBCSI  551 non-null    float64
#  3   LB2LYPCT  551 non-null    float64
#  4   LB2MOPCT  551 non-null    float64
#  5   LB2NEPCT  551 non-null    float64
#  6   LB2EOPCT  551 non-null    float64
#  7   LB2BAPCT  551 non-null    float64
#  8   LB2LYMNO  551 non-null    float64
#  9   LB2MONO   551 non-null    float64
#  10  LB2NENO   551 non-null    float64
#  11  LB2EONO   551 non-null    float64
#  12  LB2BANO   551 non-null    float64
#  13  LB2RBCSI  551 non-null    float64
#  14  LB2HGB    551 non-null    float64
#  15  LB2HCT    551 non-null    float64
#  16  LB2MCVSI  551 non-null    float64
#  17  LB2MCHSI  551 non-null    float64
#  18  LB2MC     551 non-null    float64
#  19  LB2RDW    551 non-null    float64
#  20  LB2PLTSI  551 non-null    float64
#  21  LB2MPSI   551 non-null    float64
# dtypes: float64(22)
# memory usage: 95.9 KB
# None
# ========================================
# Info for cbc4.XPT:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9165 entries, 0 to 9164
# Data columns (total 21 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SEQN      9165 non-null   float64
#  1   LBXWBCSI  8117 non-null   float64
#  2   LBXLYPCT  8116 non-null   float64
#  3   LBXMOPCT  8116 non-null   float64
#  4   LBXNEPCT  8116 non-null   float64
#  5   LBXEOPCT  8116 non-null   float64
#  6   LBXBAPCT  8116 non-null   float64
#  7   LBDLYMNO  8116 non-null   float64
#  8   LBDMONO   8116 non-null   float64
#  9   LBDNENO   8116 non-null   float64
#  10  LBDEONO   8116 non-null   float64
#  11  LBDBANO   8116 non-null   float64
#  12  LBXRBCSI  8117 non-null   float64
#  13  LBXHGB    8117 non-null   float64
#  14  LBXHCT    8117 non-null   float64
#  15  LBXMCVSI  8117 non-null   float64
#  16  LBXMCHSI  8117 non-null   float64
#  17  LBXMC     8147 non-null   float64
#  18  LBXRDW    8117 non-null   float64
#  19  LBXPLTSI  8117 non-null   float64
#  20  LBXMPSI   8117 non-null   float64
# dtypes: float64(21)
# memory usage: 1.5 MB
# None
# ========================================
# Info for cbc5.XPT:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9422 entries, 0 to 9421
# Data columns (total 21 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SEQN      9422 non-null   float64
#  1   LBXWBCSI  8544 non-null   float64
#  2   LBXLYPCT  8519 non-null   float64
#  3   LBXMOPCT  8519 non-null   float64
#  4   LBXNEPCT  8519 non-null   float64
#  5   LBXEOPCT  8519 non-null   float64
#  6   LBXBAPCT  8519 non-null   float64
#  7   LBDLYMNO  8519 non-null   float64
#  8   LBDMONO   8519 non-null   float64
#  9   LBDNENO   8519 non-null   float64
#  10  LBDEONO   8519 non-null   float64
#  11  LBDBANO   8519 non-null   float64
#  12  LBXRBCSI  8544 non-null   float64
#  13  LBXHGB    8544 non-null   float64
#  14  LBXHCT    8544 non-null   float64
#  15  LBXMCVSI  8544 non-null   float64
#  16  LBXMCHSI  8544 non-null   float64
#  17  LBXMC     8544 non-null   float64
#  18  LBXRDW    8544 non-null   float64
#  19  LBXPLTSI  8544 non-null   float64
#  20  LBXMPSI   8544 non-null   float64
# dtypes: float64(21)
# memory usage: 1.5 MB
# None
# ========================================
# Info for cbc6.XPT:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8956 entries, 0 to 8955
# Data columns (total 21 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SEQN      8956 non-null   float64
#  1   LBXWBCSI  7953 non-null   float64
#  2   LBXLYPCT  7944 non-null   float64
#  3   LBXMOPCT  7944 non-null   float64
#  4   LBXNEPCT  7944 non-null   float64
#  5   LBXEOPCT  7944 non-null   float64
#  6   LBXBAPCT  7944 non-null   float64
#  7   LBDLYMNO  7944 non-null   float64
#  8   LBDMONO   7944 non-null   float64
#  9   LBDNENO   7944 non-null   float64
#  10  LBDEONO   7944 non-null   float64
#  11  LBDBANO   7944 non-null   float64
#  12  LBXRBCSI  7953 non-null   float64
#  13  LBXHGB    7953 non-null   float64
#  14  LBXHCT    7953 non-null   float64
#  15  LBXMCVSI  7953 non-null   float64
#  16  LBXMCHSI  7953 non-null   float64
#  17  LBXMC     7953 non-null   float64
#  18  LBXRDW    7953 non-null   float64
#  19  LBXPLTSI  7952 non-null   float64
#  20  LBXMPSI   7952 non-null   float64
# dtypes: float64(21)
# memory usage: 1.4 MB
# None
# ========================================
# Info for cbc7.XPT:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9835 entries, 0 to 9834
# Data columns (total 21 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SEQN      9835 non-null   float64
#  1   LBXWBCSI  8798 non-null   float64
#  2   LBXLYPCT  8787 non-null   float64
#  3   LBXMOPCT  8787 non-null   float64
#  4   LBXNEPCT  8787 non-null   float64
#  5   LBXEOPCT  8787 non-null   float64
#  6   LBXBAPCT  8787 non-null   float64
#  7   LBDLYMNO  8786 non-null   float64
#  8   LBDMONO   8786 non-null   float64
#  9   LBDNENO   8786 non-null   float64
#  10  LBDEONO   8786 non-null   float64
#  11  LBDBANO   8786 non-null   float64
#  12  LBXRBCSI  8799 non-null   float64
#  13  LBXHGB    8799 non-null   float64
#  14  LBXHCT    8799 non-null   float64
#  15  LBXMCVSI  8799 non-null   float64
#  16  LBXMCHSI  8799 non-null   float64
#  17  LBXMC     8799 non-null   float64
#  18  LBXRDW    8799 non-null   float64
#  19  LBXPLTSI  8799 non-null   float64
#  20  LBXMPSI   8799 non-null   float64
# dtypes: float64(21)
# memory usage: 1.6 MB
# None
# ========================================
# Info for cbc8.XPT:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9929 entries, 0 to 9928
# Data columns (total 21 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SEQN      9929 non-null   float64
#  1   LBXWBCSI  8952 non-null   float64
#  2   LBXLYPCT  8925 non-null   float64
#  3   LBXMOPCT  8925 non-null   float64
#  4   LBXNEPCT  8925 non-null   float64
#  5   LBXEOPCT  8925 non-null   float64
#  6   LBXBAPCT  8925 non-null   float64
#  7   LBDLYMNO  8925 non-null   float64
#  8   LBDMONO   8925 non-null   float64
#  9   LBDNENO   8925 non-null   float64
#  10  LBDEONO   8925 non-null   float64
#  11  LBDBANO   8925 non-null   float64
#  12  LBXRBCSI  8952 non-null   float64
#  13  LBXHGB    8952 non-null   float64
#  14  LBXHCT    8952 non-null   float64
#  15  LBXMCVSI  8952 non-null   float64
#  16  LBXMCHSI  8952 non-null   float64
#  17  LBXMC     8952 non-null   float64
#  18  LBXRDW    8952 non-null   float64
#  19  LBXPLTSI  8951 non-null   float64
#  20  LBXMPSI   8951 non-null   float64
# dtypes: float64(21)
# memory usage: 1.6 MB
# None
# ========================================
# Info for cbc9.XPT:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9179 entries, 0 to 9178
# Data columns (total 21 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SEQN      9179 non-null   float64
#  1   LBXWBCSI  8384 non-null   float64
#  2   LBXLYPCT  8353 non-null   float64
#  3   LBXMOPCT  8353 non-null   float64
#  4   LBXNEPCT  8353 non-null   float64
#  5   LBXEOPCT  8353 non-null   float64
#  6   LBXBAPCT  8353 non-null   float64
#  7   LBDLYMNO  8353 non-null   float64
#  8   LBDMONO   8353 non-null   float64
#  9   LBDNENO   8353 non-null   float64
#  10  LBDEONO   8353 non-null   float64
#  11  LBDBANO   8353 non-null   float64
#  12  LBXRBCSI  8384 non-null   float64
#  13  LBXHGB    8384 non-null   float64
#  14  LBXHCT    8384 non-null   float64
#  15  LBXMCVSI  8384 non-null   float64
#  16  LBXMCHSI  8384 non-null   float64
#  17  LBXMC     8384 non-null   float64
#  18  LBXRDW    8384 non-null   float64
#  19  LBXPLTSI  8384 non-null   float64
#  20  LBXMPSI   8384 non-null   float64
# dtypes: float64(21)
# memory usage: 1.5 MB
# None
# ========================================
# Info for cbc10.XPT:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9440 entries, 0 to 9439
# Data columns (total 21 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SEQN      9440 non-null   float64
#  1   LBXWBCSI  8400 non-null   float64
#  2   LBXLYPCT  8378 non-null   float64
#  3   LBXMOPCT  8378 non-null   float64
#  4   LBXNEPCT  8378 non-null   float64
#  5   LBXEOPCT  8378 non-null   float64
#  6   LBXBAPCT  8378 non-null   float64
#  7   LBDLYMNO  8378 non-null   float64
#  8   LBDMONO   8378 non-null   float64
#  9   LBDNENO   8378 non-null   float64
#  10  LBDEONO   8378 non-null   float64
#  11  LBDBANO   8378 non-null   float64
#  12  LBXRBCSI  8400 non-null   float64
#  13  LBXHGB    8400 non-null   float64
#  14  LBXHCT    8400 non-null   float64
#  15  LBXMCVSI  8400 non-null   float64
#  16  LBXMCHSI  8400 non-null   float64
#  17  LBXMC     8400 non-null   float64
#  18  LBXRDW    8400 non-null   float64
#  19  LBXPLTSI  8400 non-null   float64
#  20  LBXMPSI   8400 non-null   float64
# dtypes: float64(21)
# memory usage: 1.5 MB
# None
# ========================================
# Info for cbc11.XPT:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8832 entries, 0 to 8831
# Data columns (total 21 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SEQN      8832 non-null   float64
#  1   LBXWBCSI  7981 non-null   float64
#  2   LBXLYPCT  7949 non-null   float64
#  3   LBXMOPCT  7949 non-null   float64
#  4   LBXNEPCT  7949 non-null   float64
#  5   LBXEOPCT  7949 non-null   float64
#  6   LBXBAPCT  7949 non-null   float64
#  7   LBDLYMNO  7948 non-null   float64
#  8   LBDMONO   7948 non-null   float64
#  9   LBDNENO   7948 non-null   float64
#  10  LBDEONO   7948 non-null   float64
#  11  LBDBANO   7948 non-null   float64
#  12  LBXRBCSI  7982 non-null   float64
#  13  LBXHGB    7982 non-null   float64
#  14  LBXHCT    7982 non-null   float64
#  15  LBXMCVSI  7982 non-null   float64
#  16  LBXMCHSI  7982 non-null   float64
#  17  LBXMC     7982 non-null   float64
#  18  LBXRDW    7982 non-null   float64
#  19  LBXPLTSI  7982 non-null   float64
#  20  LBXMPSI   7982 non-null   float64
# dtypes: float64(21)
# memory usage: 1.4 MB
# None
# ========================================
# Info for cbc12.XPT:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9307 entries, 0 to 9306
# Data columns (total 21 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SEQN      9307 non-null   float64
#  1   LBXWBCSI  8266 non-null   float64
#  2   LBXLYPCT  8250 non-null   float64
#  3   LBXMOPCT  8250 non-null   float64
#  4   LBXNEPCT  8250 non-null   float64
#  5   LBXEOPCT  8250 non-null   float64
#  6   LBXBAPCT  8250 non-null   float64
#  7   LBDLYMNO  8249 non-null   float64
#  8   LBDMONO   8249 non-null   float64
#  9   LBDNENO   8249 non-null   float64
#  10  LBDEONO   8249 non-null   float64
#  11  LBDBANO   8249 non-null   float64
#  12  LBXRBCSI  8267 non-null   float64
#  13  LBXHGB    8267 non-null   float64
#  14  LBXHCT    8267 non-null   float64
#  15  LBXMCVSI  8267 non-null   float64
#  16  LBXMCHSI  8267 non-null   float64
#  17  LBXMC     8267 non-null   float64
#  18  LBXRDW    8267 non-null   float64
#  19  LBXPLTSI  8267 non-null   float64
#  20  LBXMPSI   8267 non-null   float64
# dtypes: float64(21)
# memory usage: 1.5 MB
# None
# ========================================
# Info for cbc13.XPT:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8366 entries, 0 to 8365
# Data columns (total 22 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   SEQN      8366 non-null   float64
#  1   LBXWBCSI  7528 non-null   float64
#  2   LBXLYPCT  7523 non-null   float64
#  3   LBXMOPCT  7523 non-null   float64
#  4   LBXNEPCT  7523 non-null   float64
#  5   LBXEOPCT  7523 non-null   float64
#  6   LBXBAPCT  7523 non-null   float64
#  7   LBDLYMNO  7523 non-null   float64
#  8   LBDMONO   7523 non-null   float64
#  9   LBDNENO   7523 non-null   float64
#  10  LBDEONO   7523 non-null   float64
#  11  LBDBANO   7523 non-null   float64
#  12  LBXRBCSI  7528 non-null   float64
#  13  LBXHGB    7528 non-null   float64
#  14  LBXHCT    7528 non-null   float64
#  15  LBXMCVSI  7528 non-null   float64
#  16  LBXMCHSI  7528 non-null   float64
#  17  LBXMC     7528 non-null   float64
#  18  LBXRDW    7528 non-null   float64
#  19  LBXPLTSI  7528 non-null   float64
#  20  LBXMPSI   7528 non-null   float64
#  21  LBXNRBC   7523 non-null   float64
# dtypes: float64(22)
# memory usage: 1.4 MB
# None
# ========================================

# %%
from pathlib import Path

def merge_cbc_files(file_pattern='cbc*.XPT'):
    """
    Merge multiple CBC XPT files into a single DataFrame.
    
    Args:
        file_pattern (str): Pattern to match XPT files (default: 'cbc*.XPT')
        
    Returns:
        pandas.DataFrame: Merged data from all CBC files
    """
    # Store all dataframes
    dfs = []
    
    # Process each XPT file
    for file_path in sorted(Path('.').glob(file_pattern)):
        try:
            # Read the XPT file
            df = pd.read_sas(file_path)
            
            # Add file source
            df['source_file'] = file_path.name

 # Handle special case for file 3 (rename LB2* columns to LBX*)
            if 'LB2WBCSI' in df.columns:
                rename_dict = {
                    'LB2WBCSI': 'LBXWBCSI',
                    'LB2LYPCT': 'LBXLYPCT',
                    'LB2MOPCT': 'LBXMOPCT',
                    'LB2NEPCT': 'LBXNEPCT',
                    'LB2EOPCT': 'LBXEOPCT',
                    'LB2BAPCT': 'LBXBAPCT',
                    'LB2LYMNO': 'LBDLYMNO',
                    'LB2MONO': 'LBDMONO',
                    'LB2NENO': 'LBDNENO',
                    'LB2EONO': 'LBDEONO',
                    'LB2BANO': 'LBDBANO',
                    'LB2RBCSI': 'LBXRBCSI',
                    'LB2HGB': 'LBXHGB',
                    'LB2HCT': 'LBXHCT',
                    'LB2MCVSI': 'LBXMCVSI',
                    'LB2MCHSI': 'LBXMCHSI',
                    'LB2MC': 'LBXMC',
                    'LB2RDW': 'LBXRDW',
                    'LB2PLTSI': 'LBXPLTSI',
                    'LB2MPSI': 'LBXMPSI'
                }
                df = df.rename(columns=rename_dict)
            
            dfs.append(df)
            print(f"Processed {file_path.name}: {len(df)} rows")
            
        except Exception as e:
            print(f"Error processing {file_path.name}: {str(e)}")
    
    # Combine all dataframes
    merged_df = pd.concat(dfs, ignore_index=True)
    
    # Sort by SEQN
    merged_df = merged_df.sort_values('SEQN')
    
    return merged_df

def save_and_analyze(df, output_file='merged_cbc_data.csv'):
    """
    Save merged data and print analysis summary.
    
    Args:
        df (pandas.DataFrame): Merged DataFrame
        output_file (str): Output CSV filename
    """
    # Save to CSV
    df.to_csv(output_file, index=False)
    
    # Print summary
    print("\nMerged Data Summary:")
    print(f"Total rows: {len(df):,}")
    print(f"Total unique subjects (SEQN): {df['SEQN'].nunique():,}")
    print("\nColumns and non-null counts:")
    for col in df.columns:
        non_null = df[col].count()
        pct_non_null = (non_null / len(df)) * 100
        print(f"{col}: {non_null:,} ({pct_non_null:.1f}%)")

# Main execution
if __name__ == "__main__":
    try:
        # Merge files
        print("Starting CBC files merge...")
        merged_data = merge_cbc_files()
        
        # Save and analyze results
        save_and_analyze(merged_data)
        
        print("\nMerge completed successfully!")
        
    except Exception as e:
        print(f"An error occurred: {str(e)}")
# Out:
# Starting CBC files merge...
# Processed cbc1.XPT: 8727 rows
# Processed cbc10.XPT: 9440 rows
# Processed cbc11.XPT: 8832 rows
# Processed cbc12.XPT: 9307 rows
# Processed cbc13.XPT: 8366 rows
# Processed cbc2.XPT: 13772 rows
# Processed cbc3.XPT: 557 rows
# Processed cbc4.XPT: 9165 rows
# Processed cbc5.XPT: 9422 rows
# Processed cbc6.XPT: 8956 rows
# Processed cbc7.XPT: 9835 rows
# Processed cbc8.XPT: 9929 rows
# Processed cbc9.XPT: 9179 rows
#
# Merged Data Summary:
# Total rows: 115,487
# Total unique subjects (SEQN): 114,930
#
# Columns and non-null counts:
# SEQN: 115,487 (100.0%)
# WTPH2YR: 8,727 (7.6%)
# LBXWBCSI: 103,223 (89.4%)
# LBXLYPCT: 103,028 (89.2%)
# LBXMOPCT: 103,028 (89.2%)
# LBXNEPCT: 103,028 (89.2%)
# LBXEOPCT: 103,028 (89.2%)
# LBXBAPCT: 103,028 (89.2%)
# LBDLYMNO: 103,025 (89.2%)
# LBDMONO: 103,025 (89.2%)
# LBDNENO: 103,025 (89.2%)
# LBDEONO: 103,025 (89.2%)
# LBDBANO: 103,025 (89.2%)
# LBXRBCSI: 103,226 (89.4%)
# LBXHGB: 103,226 (89.4%)
# LBXHCT: 103,226 (89.4%)
# LBXMCVSI: 103,226 (89.4%)
# LBXMC: 103,256 (89.4%)
# LBXMCHSI: 103,226 (89.4%)
# LBXRDW: 103,226 (89.4%)
# LBXPLTSI: 103,224 (89.4%)
# LBXMPSI: 103,224 (89.4%)
# LBXNRBC: 27,256 (23.6%)
# source_file: 115,487 (100.0%)
# LB2DAY: 551 (0.5%)
#
# Merge completed successfully!

# %% [markdown]
# ##  preparing and cleaning
#
# ###  merge all files

# %%
from pathlib import Path

def merge_cbc_files(file_pattern='cbc*.XPT'):
    """
    Merge multiple CBC XPT files into a single DataFrame.
    
    Args:
        file_pattern (str): Pattern to match XPT files (default: 'cbc*.XPT')
        
    Returns:
        pandas.DataFrame: Merged data from all CBC files
    """
    # Store all dataframes
    dfs = []
    
    # Process each XPT file
    for file_path in sorted(Path('.').glob(file_pattern)):
        try:
            # Read the XPT file
            df = pd.read_sas(file_path)
            
            # Add file source
            df['source_file'] = file_path.name

 # Handle special case for file 3 (rename LB2* columns to LBX*)
            if 'LB2WBCSI' in df.columns:
                rename_dict = {
                    'LB2WBCSI': 'LBXWBCSI',
                    'LB2LYPCT': 'LBXLYPCT',
                    'LB2MOPCT': 'LBXMOPCT',
                    'LB2NEPCT': 'LBXNEPCT',
                    'LB2EOPCT': 'LBXEOPCT',
                    'LB2BAPCT': 'LBXBAPCT',
                    'LB2LYMNO': 'LBDLYMNO',
                    'LB2MONO': 'LBDMONO',
                    'LB2NENO': 'LBDNENO',
                    'LB2EONO': 'LBDEONO',
                    'LB2BANO': 'LBDBANO',
                    'LB2RBCSI': 'LBXRBCSI',
                    'LB2HGB': 'LBXHGB',
                    'LB2HCT': 'LBXHCT',
                    'LB2MCVSI': 'LBXMCVSI',
                    'LB2MCHSI': 'LBXMCHSI',
                    'LB2MC': 'LBXMC',
                    'LB2RDW': 'LBXRDW',
                    'LB2PLTSI': 'LBXPLTSI',
                    'LB2MPSI': 'LBXMPSI'
                }
                df = df.rename(columns=rename_dict)
            
            dfs.append(df)
            print(f"Processed {file_path.name}: {len(df)} rows")
            
        except Exception as e:
            print(f"Error processing {file_path.name}: {str(e)}")
    
    # Combine all dataframes
    merged_df = pd.concat(dfs, ignore_index=True)
    
    # Sort by SEQN
    merged_df = merged_df.sort_values('SEQN')
    
    return merged_df

def save_and_analyze(df, output_file='merged_cbc_data.csv'):
    """
    Save merged data and print analysis summary.
    
    Args:
        df (pandas.DataFrame): Merged DataFrame
        output_file (str): Output CSV filename
    """
    # Save to CSV
    df.to_csv(output_file, index=False)
    
    # Print summary
    print("\nMerged Data Summary:")
    print(f"Total rows: {len(df):,}")
    print(f"Total unique subjects (SEQN): {df['SEQN'].nunique():,}")
    print("\nColumns and non-null counts:")
    for col in df.columns:
        non_null = df[col].count()
        pct_non_null = (non_null / len(df)) * 100
        print(f"{col}: {non_null:,} ({pct_non_null:.1f}%)")

# Main execution
if __name__ == "__main__":
    try:
        # Merge files
        print("Starting CBC files merge...")
        merged_data = merge_cbc_files()
        
        # Save and analyze results
        save_and_analyze(merged_data)
        
        print("\nMerge completed successfully!")
        
    except Exception as e:
        print(f"An error occurred: {str(e)}")
# Out:
# Starting CBC files merge...
# Processed cbc1.XPT: 8727 rows
# Processed cbc10.XPT: 9440 rows
# Processed cbc11.XPT: 8832 rows
# Processed cbc12.XPT: 9307 rows
# Processed cbc13.XPT: 8366 rows
# Processed cbc2.XPT: 13772 rows
# Processed cbc3.XPT: 557 rows
# Processed cbc4.XPT: 9165 rows
# Processed cbc5.XPT: 9422 rows
# Processed cbc6.XPT: 8956 rows
# Processed cbc7.XPT: 9835 rows
# Processed cbc8.XPT: 9929 rows
# Processed cbc9.XPT: 9179 rows
#
# Merged Data Summary:
# Total rows: 115,487
# Total unique subjects (SEQN): 114,930
#
# Columns and non-null counts:
# SEQN: 115,487 (100.0%)
# WTPH2YR: 8,727 (7.6%)
# LBXWBCSI: 103,223 (89.4%)
# LBXLYPCT: 103,028 (89.2%)
# LBXMOPCT: 103,028 (89.2%)
# LBXNEPCT: 103,028 (89.2%)
# LBXEOPCT: 103,028 (89.2%)
# LBXBAPCT: 103,028 (89.2%)
# LBDLYMNO: 103,025 (89.2%)
# LBDMONO: 103,025 (89.2%)
# LBDNENO: 103,025 (89.2%)
# LBDEONO: 103,025 (89.2%)
# LBDBANO: 103,025 (89.2%)
# LBXRBCSI: 103,226 (89.4%)
# LBXHGB: 103,226 (89.4%)
# LBXHCT: 103,226 (89.4%)
# LBXMCVSI: 103,226 (89.4%)
# LBXMC: 103,256 (89.4%)
# LBXMCHSI: 103,226 (89.4%)
# LBXRDW: 103,226 (89.4%)
# LBXPLTSI: 103,224 (89.4%)
# LBXMPSI: 103,224 (89.4%)
# LBXNRBC: 27,256 (23.6%)
# source_file: 115,487 (100.0%)
# LB2DAY: 551 (0.5%)
#
# Merge completed successfully!

# %% [markdown]
# ## Optimize columns

# %%
df = merged_data.drop(['SEQN','WTPH2YR','LBXNRBC','source_file','LB2DAY'],axis=1)

# %%
# Mapping dictionary for renaming columns to shorter, similar names
column_mapping = {
    'LBXWBCSI': 'WBC',     # White Blood Cell Count
    'LBXLYPCT': 'LY%',     # Lymphocytes Percentage
    'LBXMOPCT': 'MO%',     # Monocytes Percentage
    'LBXNEPCT': 'NE%',     # Neutrophils Percentage
    'LBXEOPCT': 'EO%',     # Eosinophils Percentage
    'LBXBAPCT': 'BA%',     # Basophils Percentage
    'LBDLYMNO': 'LY#',     # Lymphocyte Count
    'LBDMONO': 'MO#',      # Monocyte Count
    'LBDNENO': 'NE#',      # Neutrophil Count
    'LBDEONO': 'EO#',      # Eosinophil Count
    'LBDBANO': 'BA#',      # Basophil Count
    'LBXRBCSI': 'RBC',     # Red Blood Cell Count
    'LBXHGB': 'HGB',       # Hemoglobin
    'LBXHCT': 'HCT',       # Hematocrit
    'LBXMCVSI': 'MCV',     # Mean Corpuscular Volume
    'LBXMCHSI': 'MCH',     # Mean Corpuscular Hemoglobin
    'LBXMC': 'MCHC',       # Mean Corpuscular Hemoglobin Concentration
    'LBXRDW': 'RDW',       # Red Cell Distribution Width
    'LBXPLTSI': 'PLT',     # Platelet Count
    'LBXMPSI': 'MPV',      # Mean Platelet Volume
}

# Apply renaming
df = df.rename(columns=column_mapping)

# Display the new column names to verify
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 115487 entries, 18167 to 8726
# Data columns (total 20 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   WBC     103223 non-null  float64
#  1   LY%     103028 non-null  float64
#  2   MO%     103028 non-null  float64
#  3   NE%     103028 non-null  float64
#  4   EO%     103028 non-null  float64
#  5   BA%     103028 non-null  float64
#  6   LY#     103025 non-null  float64
#  7   MO#     103025 non-null  float64
#  8   NE#     103025 non-null  float64
#  9   EO#     103025 non-null  float64
#  10  BA#     103025 non-null  float64
#  11  RBC     103226 non-null  float64
#  12  HGB     103226 non-null  float64
#  13  HCT     103226 non-null  float64
#  14  MCV     103226 non-null  float64
#  15  MCHC    103256 non-null  float64
#  16  MCH     103226 non-null  float64
#  17  RDW     103226 non-null  float64
#  18  PLT     103224 non-null  float64
#  19  MPV     103224 non-null  float64
# dtypes: float64(20)
# memory usage: 18.5 MB

# %%
df.to_csv("cbc_dataframe",index=False)
